# %%
import numpy as np
import matplotlib.pyplot as plt

# Use RAW string (r"") and forward slashes (/) - this works on Windows
# Your confirmed file
filename = r"D:\IIT\L6\FYP\ChagaSight\data\processed\2d_images\sami_trop\24028_img.npy"
img = np.load(filename)
print("Shape:", img.shape)    # (3, 24, 2048)
print("Dtype:", img.dtype)    # float32

# Plot the 3 contours
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].imshow(img[0], cmap='gray')
axs[0].set_title('RA Contour')
axs[1].imshow(img[1], cmap='gray')
axs[1].set_title('LA Contour')
axs[2].imshow(img[2], cmap='gray')
axs[2].set_title('LL Contour')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       4 # Use RAW string (r"") and forward slashes (/) - this works on Windows
#       5 # Your confirmed file
#       6 filename = r"data/processed/2d_images/sami_trop/24028_img.npy"
# ----> 8 img = np.load(filename)
#       9 print("Shape:", img.shape)    # (3, 24, 2048)
#      10 print("Dtype:", img.dtype)    # float32
#
# File d:\IIT\L6\FYP\ChagaSight\.venv\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed/2d_images/sami_trop/24028_img.npy'
